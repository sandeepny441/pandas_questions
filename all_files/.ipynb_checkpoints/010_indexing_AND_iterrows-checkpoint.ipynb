# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv('df_apple.csv')
df
# Out:
#    Product_ID Product_Type            Model Release_Date    Price In_Stock  \
# 0           1      MacBook  MacBook Pro 13"   2021-05-21  1299.99     True
# 1           2         iPad         iPad Air   2022-03-18   599.99    False
# 2           3       iPhone        iPhone 13   2023-09-24   999.99     True
# 3           4        Watch   Watch Series 7   2021-10-15   399.99     True
# 4           5      AirPods      AirPods Pro   2021-05-18   249.99    False
# 5           6      MacMini              NaN          NaN   699.99     True
# 6           7          NaN       MacMini M1   2020-11-17      NaN    False
# 7           8  MacBook Air   MacBook Air M1   2020-12-22   999.99      NaN
#
#   Category_Type
# 0       desktop
# 1        mobile
# 2        mobile
# 3      wearable
# 4      wearable
# 5       desktop
# 6       desktop
# 7       desktop

# %%
# -------indexing

# How would you set the Product_ID column as the index of the DataFrame?
# Can you demonstrate how to reset the index back to the default integer index?
# How would you create a multi-level index using the Category_Type and Product_Type columns?
# Is there a way to index the DataFrame using the Release_Date column in a way that allows you to easily select data based on the date?
# How can you use boolean indexing to select all products that are in stock (In_Stock is True)?
# Can you show how to use label-based indexing to retrieve the row data for the product with Product_ID 4?
# How would you use index slicing to get the data for the first three products in the DataFrame?
# Is it possible to change the existing index to a new index while keeping the DataFrame intact?
# How can you use the .loc method to select all products within a certain price range, say 500 to 1000?
# How would you add a new column to the DataFrame and immediately set it as the index?

# %%
# -------iterrows

# How would you use iterrows to print out each product's Product_ID and Model?
# Can you demonstrate how to calculate and print the total Price of all products using iterrows?
# How would you use iterrows to find and display all products that are in stock (In_Stock is True)?
# Is there a way to use iterrows to create a list of all models (Model column) that are of the Category_Type 'mobile'?
# How can you use iterrows to count the number of products that were released after a specific date, say '2022-01-01'?
# Can you use iterrows to print each row where the Price is greater than 500?
# How would you use iterrows to update a new column in the DataFrame, for example, adding a Discounted_Price column with a 10% reduction from the original Price?
# Is it possible to use iterrows to identify and print out any rows that have NaN values in the Release_Date or Model columns?
# How can you use iterrows to generate a dictionary where the keys are Product_ID and the values are the corresponding Model names?
# Can you demonstrate how to use iterrows to print each product's details in a formatted string, like "Product ID [Product_ID] is a [Category_Type] named [Model] costing [Price]"?
